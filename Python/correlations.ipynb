# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import adjustText as adjust_text
import ast 
import seaborn as sns
import matplotlib

df = pd.read_csv(r'D:\P\CSV_Excel\movies.csv')

df['released'] = df['released'].str.extract(r'(\w+ \d{1,2}, \d{4})')[0]
df['released'] = pd.to_datetime(df['released'])
df['year_correct'] = df['released'].astype(str).str[:4]
df['budget']=df['budget'].fillna(0).astype('int64')
df['gross']=df['gross'].fillna(0).astype('int64')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.plot(kind='scatter' ,x='budget',y='gross')
plt.title('Budget VS Gross')

plt.show()

# %%
sns.regplot(x='budget', y='gross', data=df ,scatter_kws={'color':'teal'},line_kws={'color':'red'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df_corr = df[['budget','gross','runtime','score','votes','year']]

# %%
new_corr= df_corr.corr(method='pearson')
sns.heatmap(new_corr,annot=True)

plt.title('Correlations Between Number Values')

plt.xlabel('Movie Featuers')
plt.ylabel('Movie Featuers')
plt.tight_layout()

plt.show()

# %%
df_numerized = df.copy()

for i in df_numerized.columns:
    if(df_numerized[i].dtype == 'object'):
         df_numerized[i] = df_numerized[i].astype('category')
         df_numerized[i] = df_numerized[i].cat.codes

df_numerized
# Out:
#       name  rating  genre  year   released  score      votes  director  \
# 0     6587       6      6  1980 1980-06-13    8.4   927000.0      2589
# 1     5573       6      1  1980 1980-07-02    5.8    65000.0      2269
# 2     5142       4      0  1980 1980-06-20    8.7  1200000.0      1111
# 3      286       4      4  1980 1980-07-02    7.7   221000.0      1301
# 4     1027       6      4  1980 1980-07-25    7.3   108000.0      1054
# ...    ...     ...    ...   ...        ...    ...        ...       ...
# 7663  3705      -1      6  2020 2020-10-23    3.1       18.0      1500
# 7664  1678      -1      4  2020 2020-02-07    4.7       36.0       774
# 7665  4717      -1      6  2020 2020-04-27    5.7       29.0      2061
# 7666  2843      -1      6  2020 2020-10-01    NaN        NaN      1184
# 7667  5394      -1     10  2020 2020-08-19    5.7        7.0      2165
#
#       writer  star  country    budget      gross  company  runtime  \
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df_numerized_corr = df_numerized.corr(method='pearson').copy()
sns.heatmap(df_numerized_corr,annot=True)

plt.title('Correlation between all the values in DF')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized_corr

df_numerized_unstack = df_numerized_corr.unstack()

df_numerized_unstack
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.004951
#                                 ...
# year_correct  budget          0.284783
#               gross           0.243478
#               company        -0.026492
#               runtime         0.115317
#               year_correct    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs= df_numerized_unstack.sort_values()

sorted_pairs
# Out:
# genre         budget         -0.334021
# budget        genre          -0.334021
# gross         genre          -0.234297
# genre         gross          -0.234297
#               votes          -0.145307
#                                 ...
# star          star            1.000000
# company       company         1.000000
# gross         gross           1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# Length: 256, dtype: float64

# %%
high_corr= sorted_pairs[(sorted_pairs)> .45]
high_corr
# Out:
# votes         budget          0.486862
# budget        votes           0.486862
# gross         votes           0.632834
# votes         gross           0.632834
# gross         budget          0.750157
# budget        gross           0.750157
# year          year_correct    0.967486
# year_correct  year            0.967486
# director      director        1.000000
# votes         votes           1.000000
# released      released        1.000000
# score         score           1.000000
# rating        rating          1.000000
# name          name            1.000000
# genre         genre           1.000000
# year          year            1.000000
# budget        budget          1.000000
# country       country         1.000000
# writer        writer          1.000000
# star          star            1.000000
# company       company         1.000000
# gross         gross           1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# ...
